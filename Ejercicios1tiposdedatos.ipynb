# %% [markdown]
# <a href="https://colab.research.google.com/github/apatinon/python-for-everybody/blob/main/Ejercicios1tiposdedatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 1**
# Escribir un programa que muestre por pantalla la cadena ¡Hola Mundo!.

# %%
print('¡Hola Mundo!.')
# Out:
# ¡Hola Mundo!.

# %% [markdown]
# # **Ejercicio 2**
# Escribir un programa que almacene la cadena ¡Hola Mundo! en una variable y luego muestre por pantalla el contenido de la variable.

# %%
a = str('¡Hola mundo!')
print(a)
# Out:
# ¡Hola mundo!

# %% [markdown]
# # **Ejercicio 3**
# Escribir un programa que pregunte el nombre del usuario en la consola y después de que el usuario lo introduzca muestre por pantalla la cadena ¡Hola < nombre >!, donde < nombre > es el nombre que el usuario haya introducido.

# %%
nombre = str(input('Ingrese su nombre: '))
print('¡hola',nombre,'!') #me sale despegado la exclamación, habría que ver como pegarlo, eliminando un espacio o algo así
# Out:
# Ingrese su nombre: andres
# ¡hola andres !

# %% [markdown]
# # **Ejercicio 4**
# Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética (3+2/2*5)^2

# %%
a = ((3+2)/(2*5))**2
print(a)
# Out:
# 0.25

# %% [markdown]
# # **Ejercicio 6**
# Escribir un programa que lea un entero positivo n,  introducido por el usuario y después muestre en pantalla la suma de todos los enteros desde 1 hasta n
# . La suma de los
#  primeros enteros positivos puede ser calculada de la siguiente forma: (n(n+1))/2

# %%
n = int(input('ingrese un entero positivo: '))
suma =  n * (n + 1) / 2
print("La suma de los primeros números enteros desde 1 hasta " + str(n) + " es " + str(suma))
# Out:
# ingrese un entero positivo: 4
# La suma de los primeros números enteros desde 1 hasta 4 es 10.0

# %% [markdown]
# # **Ejercicio 7**
# Escribir un programa que pida al usuario su peso (en kg) y estatura (en metros), calcule el índice de masa corporal y lo almacene en una variable, y muestre por pantalla la frase Tu índice de masa corporal es < imc > donde < imc > es el índice de masa corporal calculado redondeado con dos decimales.

# %%
peso = float(input('ingrese su peso en kg: '))
estatura = float(input('ingrese su estatura en metros: '))
imc = peso/(estatura*estatura)
print(round(imc, 2))
# Out:
# ingrese su peso en kg: 70
# ingrese su estatura en metros: 1.65
# 25.71

# %% [markdown]
# # **Ejercicio 8**
# Escribir un programa que pida al usuario dos números enteros y muestre por pantalla la < n > entre < m > da un cociente < c > y un resto < r > donde < n > y < m > son los números introducidos por el usuario, y < c > y < r > son el cociente y el resto de la división entera respectivamente.

# %%
n = int(input("ingrese el primer numero: "))
m = int(input("ingrese el primer numero: "))
c = int(n//m) #se usa el doble slash para la division entera, pilas
r = int(n%m)
print(n, 'entre', m ,'da un cociente', c ,'y un resto', r)
#Solución propuesta por la persona que diseña el ejericio:
#print(n + " entre " +  m + " da un cociente " + str(int(n) // int(m)) + " y un resto " + str(int(n) % int(m)))
# Out:
# ingrese el primer numero: 7
# ingrese el primer numero: 2
# 7 entre 2 da un cociente 3 y un resto 1

# %% [markdown]
# # **Ejercicio 9**
# Escribir un programa que pregunte al usuario una cantidad a invertir, el interés anual y el número de años, y muestre por pantalla el capital obtenido en la inversión.

# %%
inversion = float(input("ingrese la cantidad a invertir: "))
interes = float(input("ingrese la cantidad a interes anual: "))
tiempo = float(input("ingrese la cantidad de años: "))
capital = ( inversion *(1 + interes * tiempo))
print("El capital obtenido por la inversion es: " + str(capital))
# Out:
# ingrese la cantidad a invertir: 1000
# ingrese la cantidad a interes anual: 10
# ingrese la cantidad de años: 5
# El capital obtenido por la inversion es: 51000.0

# %% [markdown]
# # **Ejercicio 10**
# Una juguetería tiene mucho éxito en dos de sus productos: payasos y muñecas. Suele hacer venta por correo y la empresa de logística les cobra por peso de cada paquete así que deben calcular el peso de los payasos y muñecas que saldrán en cada paquete a demanda. Cada payaso pesa 112 g y cada muñeca 75 g. Escribir un programa que lea el número de payasos y muñecas vendidos en el último pedido y calcule el peso total del paquete que será enviado.

# %%
payasos = int(input("ingrese el numero de payasos: "))
muñecas = int(input("ingrese el numero de muñecas: "))
pmuñecas = muñecas*75
ppayasos = payasos*112
print("El pesos total del paquete es de: ", str(pmuñecas+ppayasos), "gramos")
# Out:
# ingrese el numero de payasos: 112
# ingrese el numero de muñecas: 75
# El pesos total del paquete es de:  18169 gramos

# %% [markdown]
# # **Ejercicio 11**
# Imagina que acabas de abrir una nueva cuenta de ahorros que te ofrece el 4% de interés al año. Estos ahorros debido a intereses, que no se cobran hasta finales de año, se te añaden al balance final de tu cuenta de ahorros. Escribir un programa que comience leyendo la cantidad de dinero depositada en la cuenta de ahorros, introducida por el usuario. Después el programa debe calcular y mostrar por pantalla la cantidad de ahorros tras el primer, segundo y tercer años. Redondear cada cantidad a dos decimales.

# %%
ahorro = float(input("ingrese la cantidad de dinero en la cuenta: "))
tasa = 0.04
unanio = round(ahorro * (1 + tasa) , 2)
dosanio = round(unanio * (1 + tasa ), 2)
tresanio = round(dosanio * (1 + tasa) , 2)
print("Balance tras el primer año:", unanio)
print("Balance tras el segundo año:", dosanio)
print("Balance tras el tercer año:", tresanio)
# Out:
# ingrese la cantidad de dinero en la cuenta: 10
# Balance tras el primer año: 10.4
# Balance tras el segundo año: 10.82
# Balance tras el tercer año: 11.25
